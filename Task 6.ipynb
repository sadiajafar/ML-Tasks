# %%
import matplotlib
from mpl_toolkits import mplot3d
from matplotlib import pyplot as plt
from matplotlib import cm
from matplotlib import image as mpimg
from matplotlib.pyplot import figure
#%matplolib_inline
import seaborn as sns
import numpy as np
import matplotlib.pylab as pl
from matplotlib.colors import ListedColormap

# %%
#Display image:
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
plt.title("Machine Learning")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixel scaling")
img=np.array(mpimg.imread('C:/Users/fsl/picture.PNG'))
plt.imshow(img)
plt.show()

# %%
#Crop the image:
from PIL import Image
img=Image.open(r"C:/Users/fsl/picture.PNG")
print(img.format)
print(img.size)
print(img.mode)
img.show()
left=0
top=50
right=510
bottom=200
image=img.crop((left,top,right,bottom))
image.show()
# Out:
# PNG
# (266, 190)
# P

# %%
#Randomly placed markers:
import numpy as np
import matplotlib.pyplot as plt
n1=np.random.rand(50)
n2=np.random.rand(50)
plt.scatter(n1,n2, s=60, edgecolor='black')
plt.show()

# %%
#Colour Analysis using seaborn:
from matplotlib import pyplot as plt
import seaborn as sns
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]
